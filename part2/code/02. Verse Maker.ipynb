# %%
import pandas as pd
bible_db = pd.read_csv ('bible_db.csv')
bible_db
# Out:
#        Unnamed: 0  Chapter         Book  verse_num  \
# 0               0        1      Genesis          1
# 1               1        1      Genesis          2
# 2               2        1      Genesis          3
# 3               3        1      Genesis          4
# 4               4        1      Genesis          5
# ...           ...      ...          ...        ...
# 37656       37656       18  4 Maccabees         20
# 37657       37657       18  4 Maccabees         21
# 37658       37658       18  4 Maccabees         22
# 37659       37659       18  4 Maccabees         23
# 37660       37660       18  4 Maccabees         24
#
#                                            cleaned_verse
# 0      In the beginning when God created[a] the heave...
# 1      the earth was a formless void and darkness cov...
# 2      Then God said, “Let there be light”; and there...
# 3      And God saw that the light was good; and God s...
# 4      God called the light Day, and the darkness he ...
# ...

# %%
bible_db['Book'].unique()
# Out:
# array(['Genesis', 'Exodus', 'Leviticus', 'Numbers', 'Deuteronomy',
#        'Joshua', 'Judges', 'Ruth', '1 Samuel', '2 Samuel', '1 Kings',
#        '2 Kings', '1 Chronicles', '2 Chronicles', 'Ezra', 'Nehemiah',
#        'Esther', 'Job', 'Psalm', 'Proverbs', 'Ecclesiastes',
#        'Song of Solomon', 'Isaiah', 'Jeremiah', 'Lamentations', 'Ezekiel',
#        'Daniel', 'Hosea', 'Joel', 'Amos', 'Obadiah', 'Jonah', 'Micah',
#        'Nahum', 'Habakkuk', 'Zephaniah', 'Haggai', 'Zechariah', 'Malachi',
#        'Matthew', 'Mark', 'Luke', 'John', 'Acts', 'Romans',
#        '1 Corinthians', '2 Corinthians', 'Galatians', 'Ephesians',
#        'Philippians', 'Colossians', '1 Thessalonians', '2 Thessalonians',
#        '1 Timothy', '2 Timothy', 'Titus', 'Philemon', 'Hebrews', 'James',
#        '1 Peter', '2 Peter', '1 John', '2 John', '3 John', 'Jude',
#        'Revelation', 'Tobit', 'Judith', 'Greek Esther', 'Wisdom',
#        'Sirach', 'Baruch', 'Letter of Jeremiah', 'Prayer of Azariah',
# ...

# %%
old = ['Genesis', 'Exodus', 'Leviticus', 'Numbers', 'Deuteronomy',
       'Joshua', 'Judges', 'Ruth', '1 Samuel', '2 Samuel', '1 Kings',
       '2 Kings', '1 Chronicles', '2 Chronicles', 'Ezra', 'Nehemiah',
       'Esther', 'Job', 'Psalm', 'Proverbs', 'Ecclesiastes',
       'Song of Solomon', 'Isaiah', 'Jeremiah', 'Lamentations', 'Ezekiel',
       'Daniel', 'Hosea', 'Joel', 'Amos', 'Obadiah', 'Jonah', 'Micah',
       'Nahum', 'Habakkuk', 'Zephaniah', 'Haggai', 'Zechariah', 'Malachi']
new = ['Matthew', 'Mark', 'Luke', 'John', 'Acts', 'Romans',
       '1 Corinthians', '2 Corinthians', 'Galatians', 'Ephesians',
       'Philippians', 'Colossians', '1 Thessalonians', '2 Thessalonians',
       '1 Timothy', '2 Timothy', 'Titus', 'Philemon', 'Hebrews', 'James',
       '1 Peter', '2 Peter', '1 John', '2 John', '3 John', 'Jude',
       'Revelation', 'Tobit', 'Judith', 'Greek Esther', 'Wisdom',
       'Sirach', 'Baruch', 'Letter of Jeremiah', 'Prayer of Azariah',
       'Susanna', 'Bel and the Dragon', '1 Maccabees', '2 Maccabees',
       '1 Esdras', 'Prayer of Manasseh', 'Psalm 151', '3 Maccabees',
       '2 Esdras', '4 Maccabees']

# %%
new_abridged = ['Matthew', 'Mark', 'Luke', 'John', 'Acts', 'Romans',
       '1 Corinthians', '2 Corinthians', 'Galatians', 'Ephesians',
       'Philippians', 'Colossians', '1 Thessalonians', '2 Thessalonians',
       '1 Timothy', '2 Timothy', 'Titus', 'Philemon', 'Hebrews', 'James',
       '1 Peter', '2 Peter', '1 John', '2 John', '3 John', 'Jude',
       'Revelation']

# %%
keywords = ['love, hope', 'heart']

# %%
new_test = bible_db[bible_db['cleaned_verse'].str.contains('love')]
new_test
# Out:
#        Unnamed: 0  Chapter         Book  verse_num  \
# 549           549       22      Genesis          2
# 603           603       24      Genesis         12
# 605           605       24      Genesis         14
# 618           618       24      Genesis         27
# 658           658       24      Genesis         67
# ...           ...      ...          ...        ...
# 37566       37566       15  4 Maccabees         11
# 37568       37568       15  4 Maccabees         13
# 37578       37578       15  4 Maccabees         23
# 37580       37580       15  4 Maccabees         25
# 37590       37590       16  4 Maccabees          3
#
#                                            cleaned_verse
# 549    He said, “Take your son, your only son Isaac, ...
# 603    And he said, “O Lord, God of my master Abraham...
# 605    Let the girl to whom I shall say, ‘Please offe...
# 618    and said, “Blessed be the Lord, the God of my ...
# 658    Then Isaac brought her into his mother Sarah’s...
# ...

# %%
new_test = bible_db[bible_db['Book'] == 'Psalm']
new_test
# Out:
#        Unnamed: 0  Chapter   Book  verse_num  \
# 13940       13940        1  Psalm          1
# 13941       13941        1  Psalm          2
# 13942       13942        1  Psalm          3
# 13943       13943        1  Psalm          4
# 13944       13944        1  Psalm          5
# ...           ...      ...    ...        ...
# 16396       16396      150  Psalm          2
# 16397       16397      150  Psalm          3
# 16398       16398      150  Psalm          4
# 16399       16399      150  Psalm          5
# 16400       16400      150  Psalm          6
#
#                                            cleaned_verse
# 13940                                    Happy are those
# 13941       but their delight is in the law of the Lord,
# 13942                                They are like trees
# 13943                             The wicked are not so,
# 13944  Therefore the wicked will not stand in the jud...
# ...                                                  ...
# ...

# %%
new_test[new_test['cleaned_verse'].str.contains('I will extol you')]['cleaned_verse']
# Out:
# 14167    For this I will extol you, O Lord, among the n...
# 14320    I will extol you, O Lord, for you have drawn m...
# 16321                   I will extol you, my God and King,
# Name: cleaned_verse, dtype: object

# %%
new_test[new_test['cleaned_verse'].str.contains('I will tell of the decree of the Lord ')]

#I will tell of the decree of the Lord are right the fear of the Lord
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Chapter, Book, verse_num, cleaned_verse]
# Index: []

# %%
new_test[new_test['cleaned_verse'].str.contains('lion')]
# Out:
#        Unnamed: 0  Chapter   Book  verse_num  \
# 13997       13997        7  Psalm          2
# 14050       14050       10  Psalm          9
# 14115       14115       17  Psalm         12
# 14225       14225       22  Psalm         21
# 14398       14398       34  Psalm         10
# 14772       14772       57  Psalm          4
# 15408       15408       91  Psalm         13
# 15592       15592      104  Psalm         21
#
#                                            cleaned_verse
# 13997            or like a lion they will tear me apart;
# 14050      they lurk in secret like a lion in its cov...
# 14115                They are like a lion eager to tear,
# 14225                Save me from the mouth of the lion!
# 14398            The young lions suffer want and hunger,
# 14772                             I lie down among lions
# 15408          You will tread on the lion and the adder,
# 15592               The young lions roar for their prey,

# %%
bible_db[bible_db['cleaned_verse'].str.contains(' you will be astonished')]
# Out:
#        Unnamed: 0  Chapter  Book  verse_num  \
# 26217       26217        5  John         20
#
#                                            cleaned_verse
# 26217  The Father loves the Son and shows him all tha...

# %%
import re
def text_cleaner(text):
    text = re.sub(r'--', ' ', text)
    text = re.sub(r';', '', text)
    text = re.sub(r',', '', text)
    text = re.sub(r'T', 't', text)
    text = re.sub('[\[].*?[\]]', '', text)
    #text = re.sub(r'(\b|\s+\-?|^\-?)(\d+|\d*\.\d+)\b','', text)
    #text = re.sub('[^a-zA-Z0-9\\s]+', '', text)
    text = ' '.join(text.split())
    return text

# %%
new_test_combine = [' '.join(new_test['cleaned_verse'])]
new_test_combine = new_test_combine[0]
new_test_verses = text_cleaner(new_test_combine)

# %%
import spacy
from spacy.lang.en import English

nlp = spacy.load('en_core_web_sm')
bible_doc = nlp(new_test_verses)
bible_sent = ' '.join([sent.text for sent in bible_doc.sents if len(sent.text) > 1])
bible_sent
# Out:
# 'Happy are those but their delight is in the law of the Lord they are like trees the wicked are not so therefore the wicked will not stand in the judgment for the Lord watches over the way of the righteous Why do the nations conspire the kings of the earth set themselves “Let us burst their bonds asunder He who sits in the heavens laughs then he will speak to them in his wrath “I have set my king on Zion my holy hill.” I will tell of the decree of the Lord: Ask of me and I will make the nations your heritage You shall break them with a rod of iron Now therefore O kings be wise Serve the Lord with fear kiss his feet O Lord how many are my foes! many are saying to me But you O Lord are a shield around me I cry aloud to the Lord I lie down and sleep I am not afraid of ten thousands of people Rise up O Lord! Deliverance belongs to the Lord Answer me when I call O God of my right! How long you people shall my honor suffer shame? But know that the Lord has set apart the faithful for himsel
# ...

# %%
import markovify
generator_1 = markovify.Text(bible_sent, state_size=3)

# %%
for i in range(3):
    print(generator_1.make_sentence())
#We will randomly generate three more sentences of no more than 100 characters
for i in range(3):
    print(generator_1.make_short_sentence(max_chars=100))
# Out:
# None
# None
# Happy are the people to whom such blessings fall I will extol you O Lord my God with my whole heart For great is your steadfast love come to me O God the nations have sunk in the pit that they made the Lord has made Save us we beseech you O Lord!
# Enter his gates with thanksgiving For the Lord will reign forever Praise the Lord!
# You Lord God of my praise.
# I will give great thanks to the Lord for he is good O fear the Lord trust in the Lord!

# %%
class POSifiedText(markovify.Text):
    def word_split(self, sentence):
        return ['::'.join((word.orth_, word.pos_)) for word in nlp(sentence)]
    def word_join(self, words):
        sentence = ' '.join(word.split('::')[0] for word in words)
        return sentence
#Call the class on our text
generator_2 = POSifiedText(bible_sent, state_size=3)

# %%
for i in range(5):
    print(generator_2.make_sentence())
#print 100 characters or less sentences

for i in range(5):
    
    print(generator_2.make_short_sentence(max_chars=100))
# Out:
# Who is the King of glory ? to you O Lord ?
# None
# Who can utter the mighty doings of the Lord Blessed be the Lord forever .
# Bestir yourself for my defense Vindicate me O Lord in your anger Be gracious to me O God for in you I take refuge or like a lion eager to tear Rise up O Lord !
# None
# Let Israel be glad in its Maker Let them praise your great and awesome name .
# Bestir yourself for my defense Vindicate me O Lord you have searched me and known me .
# Have you not rejected us O God of my praise .
# Why do you hide your face from me .
# I will tell of the decree of the Lord Blessed be the Lord forever .

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sarakay/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop = stopwords.words('english')
bible_db["verse_stopped"] = bible_db["cleaned_verse"].apply(lambda x: ' '.join([word for word in x.split() if word.lower() not in (stop)]))

# %%
stop
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
bible_db["verse_stopped"].head()
# Out:
# 0              beginning God created[a] heavens earth,
# 1    earth formless void darkness covered face deep...
# 2                        God said, “Let light”; light.
# 3    God saw light good; God separated light darkness.
# 4    God called light Day, darkness called Night. e...
# Name: verse_stopped, dtype: object

# %%
from collections import Counter
Counter(" ".join(bible_db["verse_stopped"]).split()).most_common(100)
# Out:
# [('shall', 5337),
#  ('Lord', 4441),
#  ('one', 2830),
#  ('said', 2456),
#  ('God', 2259),
#  ('son', 1827),
#  ('people', 1726),
#  ('said,', 1658),
#  ('him,', 1649),
#  ('you,', 1614),
#  ('came', 1570),
#  ('Lord,', 1495),
#  ('them,', 1438),
#  ('king', 1404),
#  ('went', 1334),
#  ('may', 1265),
#  ('land', 1239),
#  ('made', 1205),
#  ('house', 1200),
#  ('come', 1195),
#  ('day', 1028),
#  ('go', 1014),
#  ('us', 1012),
#  ('me,', 999),
#  ('also', 996),
#  ('like', 991),
#  ('put', 903),
#  ('make', 902),
#  ('Israel', 866),
#  ('brought', 853),
#  ('God,', 839),
#  ('among', 836),
#  ('King', 829),
#  ('give', 827),
#  ('great', 824),
#  ('says', 821),
#  ('let', 819),
#  ('took', 808),
#  ('two', 806),
#  ('sent', 800),
#  ('know', 796),
#  ('man', 774),
#  ('set', 764),
#  ('would', 746),
#  ('saw', 707),
#  ('sons', 704),
#  ('Jesus', 702),
#  ('him.', 694),
#  ('them.', 693),
#  ('upon', 674),
#  ('take', 673),
#  ('hundred', 673),
#  ('David', 666),
#  ('gave', 665),
# ...
